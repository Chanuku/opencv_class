# %%
import cv2 as cv

# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
capture = cv.VideoCapture('./110947.mp4')

# %%
capture
# Out:
# <VideoCapture 00000293858C4970>

# %%
dir(capture)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'get',
#  'getBackendName',
#  'grab',
#  'isOpened',
#  'open',
#  'read',
#  'release',
#  'retrieve',
#  'set']

# %%
capture.isOpened()
# Out:
# True

# %%
ret,frame = capture.read()

# %%
ret #제대로 읽어왔는지 확인
# Out:
# True

# %%
frame
# Out:
# array([[[ 55,  47,  42],
#         [ 54,  46,  41],
#         [ 52,  44,  39],
#         ...,
#         [ 38,  26, 122],
#         [ 46,  34, 130],
#         [ 56,  44, 140]],
#
#        [[ 55,  47,  42],
#         [ 54,  46,  41],
#         [ 52,  44,  39],
#         ...,
#         [ 40,  28, 124],
#         [ 56,  44, 140],
#         [ 70,  58, 154]],
#
#        [[ 57,  47,  42],
#         [ 56,  46,  41],
#         [ 54,  44,  39],
#         ...,
#         [ 40,  28, 124],
#         [ 56,  44, 140],
#         [ 70,  58, 154]],
#
#        ...,
#
#        [[179, 166, 157],
#         [177, 164, 155],
#         [175, 162, 153],
#         ...,
#         [108, 126, 160],
#         [109, 127, 161],
#         [108, 126, 160]],
#
#        [[179, 166, 157],
#         [179, 166, 157],
#         [181, 168, 159],
#         ...,
#         [108, 126, 160],
#         [109, 127, 161],
#         [108, 126, 160]],
#
#        [[178, 165, 156],
#         [180, 167, 158],
#         [186, 173, 164],
#         ...,
#         [108, 126, 160],
#         [109, 127, 161],
#         [108, 126, 160]]], dtype=uint8)

# %%
cv.imshow('win',frame)
cv.waitKey(5000)
cv.destroyWindow('win')

# %%
plt.imshow(frame) #plt이미지는 RGB로 이미지출력함,(cv는 RGB>BGR) 그래서 색이이상하게나옴

# %%
frame.shape
# Out:
# (540, 960, 3)

# %%
b = frame[:,:,0] #bgr의 b채널
g = frame[:,:,1] #bgr의 g채널
r = frame[:,:,2] #bgr의 r채널
b.shape
print(b.shape)
plt.imshow(b, cmap='gray')
plt.title('bluechannel')
cv.imwrite('blue.png',b)
# Out:
# (540, 960)
# True
